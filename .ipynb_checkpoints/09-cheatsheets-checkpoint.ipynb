# %% [markdown]
# # Lecture 9: Observables, Hermitian operators, measurement and uncertainty, Particle on a circle, Uncertainty

# %% [markdown]
# Lecture 9
#
#   B. Zwiebach March 3, 2016
#
# Contents
# 1 Observables and Hermitian operators	1
# 2 Uncertainty	6
# 1 Observables and Hermitian operators
# Let’s begin by recalling the definition of a Hermitian operator. The operator Qˆ is Hermitian if for the class of wavefunctions ? we work with,
# r dx ?? Qˆ?2 = r dx (Qˆ?1)??2 .	(1.1)
# We will sometimes use a briefer notation for the integrals of pairs of functions:
# (1.2)
# Note that for any constant a
# (a? , ? ) = a?(? , ? ) ,	(? , a? ) = a(? , ? ) .	(1.3)
#
# With this notation the condition of Hermiticity is more briefly stated
# Qˆ  is Hermitian:	(?1, Q?2) = (Q?1, ?2) .	(1.4)
# The expectation value of Qˆ was defined by
#                               Q	= r dx ?? Qˆ? = (? , Qˆ? .	(1.5) For this formula to make sense, the state ? must be normalized.
# Claim 1. The expectation value of a Hermitian operator is real. To prove this we complex conjugate the above definition. The complex conjugate of the integral is the integral of the complex conjugate of the integrand, therefore
#
# ( Q  ?
#
# = r dx (?? Qˆ? ? = r dx ?(Qˆ?)? = r dx (Qˆ?)?? .	(1.6)
#
#
# Note that Qˆ? is a wavefunction, so it makes sense to take its complex conjugate (we never have to think of conjugating Qˆ). Using the Hermiticity of the operator, we move it into ? to get
# ( Q  ?  = r dx ??Qˆ? = Q  ,	(1.7)
#
# thus showing that the expectation value is indeed real.
# Claim 2. The eigenvalues of a Hermitian operator are real. Assume the operator Qˆ has an eigenvalue
# q1 associated with a normalized eigenfunction ?1(x):
# Qˆ?1(x) = q1?1(x) .	(1.8)
# Now compute the expectation value of Qˆ in the state ?1:
#                   Qˆ ?1 = (?1 , Qˆ?1) = (?1 , q1 ?1) = q1(?1 , ?1) = q1 .	(1.9)
# By claim 1, the expectation value is real, and so is the eigenvalue q1, as we wanted to show. Note the
# interesting fact that the expectation value of Qˆ on an eigenstate is precisely given by the corresponding eigenvalue.
# Consider now the collection of eigenfunctions and eigenvalues of the Hermitian operator Qˆ:
# Qˆ ?1(x) = q1?1(x) ,	(1.10)
# Qˆ ?2(x) = q2?2(x) ,	(1.11)
# .
#
# The list may be finite or infinite.
# Claim 3. The eigenfunctions can be organized to satisfy orthonormality:
#                             (?i, ?j) = r dx ??(x)?j(x) = ?ij .	(1.12)
# For i = j, this is just a matter of normalizing properly each eigenfunction, which we can easily do. The equation also states that different eigenfunctions are orthogonal, or have zero overlap. We now
#
# explain why this is so for i
# ways. First
#
# j with qi /= qj. Indeed, for this we evaluate (?i, Qˆ?j) in two different
# (?i, Qˆ?j) = (?i, qj?j) = qj(?i, ?j) ,	(1.13)
#
# and second, using Hermiticity of Qˆ, and the reality of the eigenvalues
# (?i, Qˆ?j) = (Qˆ?i, ?j) = (qi?i, ?j) = qi(?i, ?j ) .	(1.14)
# Equating the final right-hand sides in the two evaluations we get
#
# (qj ? qi) (?i , ?j) = 0.	(1.15)
# Since the eigenvalues were assumed different, this proves that (?i, ?j) = 0, as claimed. This is not yet a full proof of (1.12) because it is possible to have degeneracies in the spectrum, namely, different eigenfunctions with the same eigenvalue. In that case the above argument does not work. One must then show that it is possible to choose linear combinations of the degenerate eigenfunctions that are mutually orthogonal (the orthogonality with the eigenfunctions beyond the degenerate space is
# automatic). This is done in 8.05!
#
# Claim 4. The eigenfunctions of Qˆ for a complete set of basis functions. Any reasonable ? can be
# written as a superposition of Qˆ eigenfunctions. (This is the so-called spectral theorem, which is proven in 8.05 in the finite-dimensional case.) This means that
#
#
# (1.16)
#
#
# with calculable coefficients ?i. Indeed, if we know the eigenfunctions we have that ?i is calculated doing the integral of ?? against ?:
# (1.17)
#
# We quickly prove this by doing the integral
# r dx ??(x)?(x) = r dx ??(x) L ?j?j(x) = L ?j r dx ??(x)?j(x) = L ?j?ij = ?i . (1.18)
#
# The condition that ? is normalized implies a condition on the coefficients ?i. We have
# r dx ??(x)?(x) = r dx L ????(x) L ?j?j(x)
# i	j
# = L ???j r dx ??(x)?j(x)	(1.19)
#
# ?	?
# i	i
# i,j	i
#
# so that the normalization of ? implies that
# |?i|2 = 1 .	(1.20)
# i
#
#    We are finally in the position to state the measurement postulate. This is the way in which we understand that Hermitian operators represent observables and learn the rules that they follow.
# Measurement Postulate: If we measure the Hermitian operator Qˆ in the state ?, the possible outcomes for the measurement are the eigenvalues q1, q2,	The probability pi to measure qi is given by
#
# pi = |?i| ,	(1.21)
# where ?(x) = Li ?i?i(x). After the outcome qi, the state of the system becomes
# ?(x) = ?i(x) .	(1.22)
# This is called the collapse of the wavefunction.
# The collapse of the wavefunction implies that immediately after the measurement that yielded qi
#
# a repeated measurement of Qˆ
#
# will yield qi with no uncertainty. A small subtlety occurs if we have
#
# degenerate eigenstates. Suppose the wavefunction contains a piece
#
# ? = (?i?i + ?k?k) + . . .	(1.23)
#
# where ?i and ?k happen to have the same eigenvalue q and the dots represent other terms. Then if we measure q the state after the measurement collapses to the sum of those two terms
#  ?i?i + ?k?k
# ? =   |? |2 + |? |2 ,	(1.24)
#
# with the square root denominator included to provide the proper normalization to ?. As a consistency check note that the probabilities pi to find the various eigenvalues as outcomes properly add to one:
#
#
# pi =
# i
#
# |?i|2
# i
#
# = 1 ,	(1.25)
#
#
# by the normalization condition for ? given in (1.20). The measurement postulate follows the Copen- hagen interpretation of quantum mechanics.
#    Note that the measurement postulate uses the property that any vector in a vector space can be written as a sum of different vectors in an infinite number of ways. If we are to measure Qˆ1 we expand the state in Qˆ1 eigenstates, if we are to measure Qˆ2 we we expand the state in Qˆ2 eigenstates, and so on and so forth. Each decomposition is suitable for a particular measurement. Each decomposition
# reveals the various probabilities for the outcomes of the specific observable.
# Exercise: Use the expansion ? = Li ?i?i to compute the expectation value Q . We find
#  Qˆ = r dx L ????(x) Qˆ L ?j?j(x)
# = L ???j r dx ??(x)Qˆ?j(x)
# i,j	(1.26)
# = L ???jqj	dx ??(x)?j(x)
#
# = L ???jqj?ij = L |?i|2qi = L piqi.
# i,j	i	i
#
#
# This matches our expectations: the expectation value of Qˆ
#
# is the sum of the possible outcomes qi
#
# multiplied by the corresponding probabilities pi. This is a nice consistency check on our definition of expectation values.
#
# Example. Free particle on the circle x ? [0, L].
# We imagine the points x = 0 and x = L identified to form a circle of circumference L. A wavefunction ?(x) on the circle must satisfy the periodicity condition
#
# ?(x + L) = ?(x) ,	(1.27)
#
# Assume that at some fixed time we have the wavefunction
#
#
#
#   2  1
#
#
#
#
#
#
# 2πx	 2
#
#
# 6πx
#
#
#
#
#
# This wavefunction satisfies the periodicity condition, as you should check. We want to know what are the possible values of the momentum and their corresponding probabilities.
#
#    Given our discussion, we must find the set of momentum eigenstates and rewrite the wavefunction as a superposition of such states. Momentum eigenstates are exponentials of the form eikx. Two things happen on the circle that do not happen in free space. First the momentum will be quantized as a consequence of the periodicity condition (1.27). Second, since space here is of finite length, the momentum wavefunctions will be normalizable. Consider the periodicity condition as applied to eikx. We need
# eikx = eik(x+L)	?	eikL = 1	?	kL = 2πm ,  m ? Z .	(1.29)
# Note that m can be any integer, positive, negative, or zero. We thus write for the momentum eigen- states, labeled by m
# 2πimx
# ?m(x) = N e  L	,	(1.30)
# with N a real normalization constant. The normalization condition gives
# r L	2	2 r L	2	 1
#
# 1 =	|?m(x)| dx = N	dx = N L	?	N = √L .
#
# (1.31)
#
# 0	0
# Therefore our momentum eigenstates are
# ? (x) =	1
# L
#
#
#
#
#
#
#
# 2πimx
# e  L	,
#
#
#
#
# (1.32)
#
# and these are states with momentum pm, which is calculated as follows
# n ∂	2π mn	2π mn
#
# pˆ?m =
#
# i ∂x?m =
#
# L	?m
#
# ?	pm =	L	.
#
# (1.33)
#
# Now that we are equipped with the momentum eigenstates we must simply rewrite the wavefunction (1.28) as a superposition of such states:
#
#
#
#   2 1  1
#
#   2πix
#
#
#
# ? 2πix
#
#
# 2 1 1
#
#
#
# 6πix
#
#
#
# ? 6πix
#
# 3 2i	L
# We then recognize that we have
#
# 3 2	L
#
#
#
#   2 1	 2 1	1	1
#
# ?(x) =
#
# 3 2i ?1(x) ?	3 2i ??1(x) + √3 ?3(x) + √3 ??3(x) .	(1.35)
#
#
# This is our key result: the original wavefunction written as a superposition of momentum eigenstates ?m(x). We can now give the possible values p of the momentum and their corresponding probabili- ties P :
#
# 2πn
# p =	,	P  =
#
#
#
# 1  2 1 12
#
# = 1 ,
#
# L	1	3 2i 1	6
#
# p = ?	,	P  = 1?	1	=	,
# 2πn	2 1 2	1
#
#
#
# L
# 6πn
# p =	,	P
#
# = 1
#
# 3 2i 1
# 1	=
#
#
#
# 6	(1.36)
# 1 ,
#
# L	1  31	3
#
#
# 6πn	1 2
# p = ?	,	P  =
#
# = 1 .
#
# L	1	31	3
#
# 2 Uncertainty
# For random variables, the uncertainty is the standard deviation—the square root of the expected value of the square of deviations from the average value. Let Q be a random variable that takes on values Q1, . . . , Qn with probabilities p1, . . . , pn, respectively. The expected value is
#
# Q =	piQi ,	(2.37)
# i
#
# and the variance (the square of the standard deviation) is
#
# (∆Q)2  ?	pi(Qi ? Q)2 .	(2.38)
# i
# This definition makes it clear that if ∆Q = 0, then the random variable is constant: each term in the above sum must vanish, making Qi = Q¯, for all i. We find another useful expression by expanding the above definition
# (∆Q)2 = L p Q2 ? 2 L p Q Q + L p Q2
#
# i  i	i  i	i
# i	i	i
#
# (2.39)
#
# where we used Li pi = 1. Therefore
#
# = Q2 ? 2Q Q + Q2 = Q2 ? Q2 ,
#
# (∆Q)2  = Q2 ? Q2 .	(2.40)
#
#
# Since, by definition (∆Q)2 ≥ 0, we have the interesting inequality
# Q2  ≥ Q2 .	(2.41)
#
#    Now let us consider the quantum mechanical case. We have already defined expectation values of Hermitian operators, so we can now mimic the definition (2.40) and declare that the uncertainty ∆Qˆ? of an operator in a state ? is a real number whose square is given by
#
#
# (∆Q)2
#
# = Q2 ? ? ( Q ?)2.	(2.42)
#
#
# Sometimes for brevity, we omit the label for the state,
#
# (2.43)
#
#
# Claim 1. The uncertainty can also be written as the expectation value of the square of the difference between the operator and its expectation value:
#                               (∆Q)2 = (Qˆ ? Qˆ 2 .	(2.44) Indeed, expanding the right hand side we have
# <Qˆ2 ? 2 Qˆ Qˆ + Qˆ 2) =  Qˆ2 ? 2 Qˆ Qˆ + Qˆ 2 =  Qˆ2 ? Qˆ 2 .	(2.45)
#
# Claim 2. The uncertainty can be written as the integral of the square of the norm of (Qˆ ? Qˆ )?:
# r ∞	1	1
# Indeed to prove this we begin with (2.44) By a very similar proof, we can show this is equivalent to (∆Q)2 =  (Qˆ ? Q 2 = r dx ?? Qˆ ? Q 2? .	(2.47)
# Using the Hermiticity of Qˆ and the reality of Qˆ we can bring one of the two factors to act on ??:
#
# 2	r	 ( ˆ	 ?
#
# r	1 ˆ	1
#
# (∆Q)	=	dx	Q ? Q ?
#
# (Q ? Q )? =
#
# dx	Q ? Q	.	(2.48)
#
# This completes the proof of claim 2.
#
# If ∆Q = 0, then by claim 2, we must have that for all x:
# (Q ? Q )?(x) = 0 ,	?	Qˆ?(x) = Qˆ ?(x) .	(2.49)
# We see that ? is an eigenstate of Qˆ, which indeed means there is no uncertainty in the measurement. Of course if ? is an eigenstate of Qˆ then again Qˆ? = Qˆ ? and the uncertainty vanishes. All in all, we have established the equivalence
#
#
# (2.50)
#
#
#
# Andrew Turner transcribed Zwiebach’s handwritten notes to create the first LaTeX version of this document.
#
# MIT OpenCourseWare https://ocw.mit.edu
#
#
#
# 8.04 Quantum Physics I
# Spring 2016
#
#
#
# For information about citing these materials or our Terms of Use, visit: https://ocw.mit.edu/terms.
