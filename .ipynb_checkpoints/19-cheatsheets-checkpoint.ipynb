# %% [markdown]
# ## Lecture 19: Levinson’s Theorem, Resonances, Modeling the Resonance

# %% [markdown]
# Lecture 19
#
#   B. Zwiebach April 28, 2016
#
# Contents
# 1 Levinson’s Theorem	1
# 2 Resonances	3
# 3 Modeling the Resonance	6
#
# 1 Levinson’s Theorem
# LLeevviinnssoonn’ss theorem relates the number Nb of bound states of a given potential to the excursion of the phase shift ?(E) as the energy goes from zero to infifinniitty:
#
# (1.1)
#
#
# To prove this result consider an arbitrary potential V (x) of range R, with a wall at x = 0. This potential, shown to the left in Figure 1, has a number of bound states, all of which are non-degenerate and can be counted. There is also a set of positive energy eigenstates: the scattering states that, belonging to a continuum, cannot be counted. Our proof requires the possibility of counting states, so we will introduce a second infinite wall, placed at x = L for large L. Of course, this will change the spectrum, but as L becomes larger and larger the changes will become smaller and smaller. We think of L as a regulator for the potential that discretizes the spectrum and thus enables us to enumerate the states. It does so because with two walls, the potential becomes a wide iinnfifinnite well and all states become bound states. The potential with the regulator wall is shown to the right in Figure 1.
#
#
# Figure 1: Left: An arbitrary one-dimensional potential V (x) of range R. Right: The same potential with a regulator wall placed at x = L.
#
#    The key of the proof will be to compare the counting of states in the regulated V =/= 0 potential to the counting of states in the V = 0 potential, also regulated with a second wall at x = L. Consider therefore the regulated V = 0 potential and the positive energy eigenstates. These correspond to the wavefunction ?(x) = sin kx, with the second wall requiring ?(x = L) = 0. We thus have
#
# kL = nπ,	with	n = 1, 2, . . .	(1.2)
#
# The values of k are now quantized. Let dk be an iinnfifinniitteessiimmaall interval in wavenumber with dn the number of states in dk when V = 0. Thus,
#
# dk L = dn π
#
# L
# ?	dn =	dk .	(1.3)
# π
#
#
# Figure 2: With the regulator wall the wavenumber k takes discrete values. dk is an iinnfifinniitteessiimmaall interval in k
# space.
#
# When V (x) /== 0, the solutions for x > R, all of which are positive energy solutions, have the form
# ?(x) = ei? sin(kx + ?) .	(1.4)
# The boundary condition ?(L) = 0 implies a quantization
# kL + ?(k) = ntπ,	(1.5)
# with nt integer. We can again diiffffeerentiate to determine the number of positive energy states dnt in
#
# the interval dk, with V
#
# =/= 0:
# dkL + d? dk = dntπ
#
# ?	dnt = Ldk + 1  d?  dk .	(1.6)
#
#
# The number of positive energy solutions lost in the interval dk as we turn on the potential V is given by dn ? dnt, which can be evaluated using (1.3) and (1.6):
# dn ? dnt = ? 1  d? dk  .	(1.7)
#
# The total number of positive energy solutions lost as the potential V is turned on is given by integrating the above over the full range of k:
#
# # of positive energy solutions lost as V turns on = ?
#
# r ∞ 1 d?
#
# dk = ?
#
# 1
# (?(∞) ? ?(0)) .	(1.8)
#
# 0	π dk	π
#
#
# Figure 3: The positive energy states of the V = 0 setup shift as the potential is turned on and some can become bound states.
#
#    Although we lose a number of positive energy solutions as the potential V is turned on, states do not disappear. As one turns on the potential from zero to V continuously, we can track each energy eigenstate and no state can disappear! If we lose some positive energy states those states must now appear as negative energy states, or bound states! Letting Nb denote the number of bound states in
# the V	0 potential, the result in (1.8) implies that
# 1
#
#
#
# This is what we wanted to prove!
#
# Nb =
#
# (?(0) ? ?(∞)) .	(1.9)
# π
#
#
# 2 Resonances
# We have calculated the time delay ∆t = 2n?t(E) associated with the reflected wavepacket that emerges from the range R potentials we have considered. If the time delay is negative, the reflected wavepacket emerges ahead of time. We can ask: Can we get an arbitrarily large negative time delay? The answer is no. A very large time delay would be a violation of causality. It would mean that the incoming packet is reflected even before it reaches x = R, which is impossible. In fact, the largest negative time delay would be realized (at least classically) if we had perfect reflection when the incoming packet hits
# x = R. If this happens, the time delay would be ? 2R , where v0 is the velocity of the packet. Indeed,
# 2R is the time saved by the packet that did not have to go in and out the range. Thus we expect
# 0
#
# time delay = 2n d?
# dE
#
# 2R
# ≥ ?	.	(2.1)
# v0
#
# This can be simplified a bit by using k derivatives
#
# 2n d?
#
#
# =  2n
# 1
# d?
# =
# 2
# d?
#
#
#
# 2R
# ≥ ?	,	(2.2)
#
#
# which then gives the constraint
#
# dE	dE dk	v dk	v
# dk
#
#
# d?
#
# ≥ ?R .	(2.3)
# dk
# The argument was not rigorous but the result is rather accurate, receiving corrections that vanish for packets of large energy.
# Alternatively, we can ask: Can we get an arbitrarily large positive time delay? The answer is
# yes. This can happen if the wave packet gets temporarily trapped in the potential. In that case we would expect the probability amplitude to become large in the 0 < x < R region. If the wavepacket is trapped for a long time we have a resonance. The state is a bit like a bound state in that it gets localized in the potential, at least for a while. In order to get a resonance it helps to have an attractive potential and a positive energy barrier. We can achieve that with the potential
#
# ?? ∞
#
# for	x ≤ 0
#
# V (x) =
#
# ?V0	for	0 < x < a
# V1	for	a < x < 2a
# ?? 0	for	x > 2a .
#
# (2.4)
#
#
# The potential, with V0, V1 > 0, is shown in figure 4. In order to have a resonance we take explore energies in the range zero to V1. In such range of energies we can expect to find some particular values
#
# that lead to resonant behavior, namely, large time delay and large amplitude for the wavefunction in the well.
#
#
# Figure 4: We search for resonances with energy E in the range (0, V1). In this range the V1 barrier produces a classically forbidden region x ? (a, 2a), that can help localize the amplitude around the well.
#
# Given the three relevant regions in the potential we ddeefifinnee
# kt2 = 2m(E + V0) ,	?2 = 2m(V1 ? E) ,	k2 = 2mE .	(2.5)
# n2	n2	n2
# In the region 0 < x < a we must use trigonometric functions of ktx. In the region a < x < 2a we use hyperbolic functions of ?a and in the region x > 2a we use the canonical solution with phase shift and wavenumber k. In the middle region a < x < 2a we could use a combination of solutions
#
#
# {e?x, e??x},	or
#
# {cosh ?x , sinh ?x} ,	or
#
# { cosh ?(x ? a) , sinh ?(x ? a) } .	(2.6)
#
#
# The last pair is most suitable to implement directly the continuity of the wavefunction at x = a. So we can write for the wavefunction ?(x):
# A sin(ktx)	0 < x < a
# ?(x) =	A sin(kta) cosh ?(x ? a) + B sinh ?(x ? a)	a < x < 2a	(2.7)
# ??ei? sin(kx + ?)	x > 2a
# After implementing the remaining boundary conditions we can solve for the phase shift ?. After a modest amount of work one fifinnddss::
#
#
# tan(2ka + ?) =
#
# ka	sin kta cosh ?a + kt cos kta sinh ?a
# ·· 	?	 .	(2.8)
#
#
# ?a	sin kta sinh ?a + kt cos kta cosh ?a
#
# This expression is fairly intricate so it is best to do numerical work. For this we defifine
#
# 2	2mV0a2	2	2mV1a2
# z0  =	n2	,	z1  =	n2	,	u ?? ka .	(2.9)
# which allow us to express both kta and ?a as functions of u
# (kta)2 = z2 + u2 ,	(?a)2 = z2 ? u2 .	(2.10)
# 0	1
#
# At this point (2.8) can be used to determine ? as a function of u = ka and the constants z0, z1. Suppose we pick values for our parameter controlling equations. In Figure 5 we show results for z2 = 1 and
# z2 = 5.
#
#
# Figure 5: Plot of various quantities as a function of u = ka, with the potential characterized by z2 = 1 and z2 = 5. (a) ?(E) increases quickly around u? = 1.85, or equivalently E = 0.69V1, crossing ?π/2 and signaling resonant behavior. (b) Plot of |As|2 = sin2 ?, showing peaks each time |?| = π/2. (c) The coeeffifficciieennt |A| of the wavefunction at the well peaks at the resonance, showing high probability of fifinnddiinngg the particle at the well.
# (d) The time delay is positive and peaks at resonance.
#
#    Consider part (a) of the fifigguurree,, showing ?(ka). At the beginning ? decreases linearly, a sign of a negative time delay, as the low energy waves rreeflfleecctt at the edge x = 2a of the V1 barrier. As ? crosses
# ?π/2 there is no resonance, even though |As|2 = sin2 ? is equal to one. Indeed we see no bump in the amplitude |A|. As the energy is increased and u = u?? = 1.8523 we get a resonance. This time ? is increasing rapidly and ? crosses ?π/2 again, making |As|2 = 1. The signal of resonance is the very
#
# high |A| the peak in the time delay. This time delay reaches the value of about 14, meaning the delay
# is fourteen times the free transit time 4a/v0!
#
# 3 Modeling the Resonance
# We would like to have further insight into the nature of resonances. In particular we want to appreciate the general features of the phenomenon. Additionally, so far we can identify resonances by looking at the behavior of ? but, can we fifinndd an equation that ddeefifinneess resonances?
#    As a fifirrsstt step, we model the behavior of a phase near resonance. Recalling that a resonance requires |?| cross the value π/2 and that ?, physically, is the same as ? increased or decreased by multiples of π we can choose to have ? vary from nearly zero to nearly π. We can achieve this with
# the following simple function.
#
# ? = tan?1   ?	 ,	with	? > 0 ,	? > 0 .	(3.1)
#
# here ? and ? are positive constants with the same units as k. To see what this function does, we fifirrsstt
# plot the argument of the arc tangent at the top of Figure 6. Note that the argument varies quickly in the region (? ? ?, ? + ?). The variation of the associated phase ? is shown in the fifigguurree below. To have a sharp increase in the phase we must have small ? compared to ?.
#
#
# Figure 6: The constant ? must be small compared to ? to obtain a sharp variation. A resonance, as shown here requires ? increasing with energy.
#
# Two relatively short calculations give us further insight:
#
# d?
#
# 1	2	2	?2
#
# dk kk=?	?
#
# |?s|
#
# =  sin
#
# ? =  ?2 + (? ? k)2 .	(3.2)
#
# The fifirrsstt one informs us that, all things being equal, the delay is large if ? is small. The second gives the norm-squared of the scattering amplitude as a function of k, with a peak at k = ?. This equation is most famously expressed in terms of the energy. For this we note that
#
# n2	2	2
#
# n2	n2
#
# E ? E? = 2m (k
#
# ? ? ) =	(k + ?)(k ? ?) ~
# 2m
#
# (2?)(k ? ?) ,	(3.3)
# 2m
#
# when working with k ≈≈ ?. It thus follows that
# 2	m2	2
#
# and therefore
#
# (k ? ?)
#
# ~ n4?2 (E ? E?) ,
#
# (3.4)
#
# |?s|2 ~
#
# ?2	1 ?2
# = 	4	 ,	(3.5)
#
# ?2 +  m2  (E ? E )2	(E ? E?)2 + 1 ?2
# n4?2	?	4
# Where we have ddeefifinneedd the constant ? with units of energy:
# 1  2	n4?2?2	2??n2
#
# 4 ? =	m2
#
# ?	? =
#
# .	(3.6)
# m
#
# The energy dependence of |?s|2 follows the so-called Breit-Wigner distribution,
# (3.7)
# The distribution is shown in Figure 8. The peak value for |?s|2 is attained for E = E? and is one. We call ? the width at half-maximum because the value of |?s|2 at E = E? ±± 1 ? is one-half. Small ?
# corresponds to a narrow width, or a narrow resonance.
#
#
# Figure 7: The Breit-Wigner distribution. ? is the width of the distribution at half maximum.
#
# To understand better the ssiiggnniifificcaannccee of ? we ddeefifinnee the associated time ? , called the lifetime of the resonance:
# n	m
# ? ??	=	.	(3.8)
# ?	2??n
#
# As you probably would expect, the lifetime is closely related to the time delay associated with a wavepacket of mean energy equal to the resonant energy. Indeed, we can evaluate the time delay ∆∆t for k = ? to get
#
# ∆∆t = 2n d?
#
# = 2n dk d?
#
# =	2n   1  =
#
#
# 2n	2m
# =
#
#
#
# = 4? .	(3.9)
#
# We therefore conclude that the lifetime and the time delay are the same quantity, up to a factor of four.
# (3.10)
#
#    Unstable particles are sometimes called resonances. The Higgs boson, discovered in 2012, is an unstable particle with mass 125 GeV. It can decay into two photons, or into two ttaauu’ss,, or into a b¯b pair, among few possibilities. The width ? associated to the particle is 4.07 Mev (±±4%). Its lifetime ? is about 1.62 ?? 10?22 seconds!
#    We now try to understand resonances more mathematically. We saw that, at resonance, the norm of As reaches a maximum value of one. Let us explore when As is large. We have
#
#
# A	= sin ? ei? =
#
# sin ?
# =
#
# sin ?
#
# tan ?
# =
#
#
# .	(3.11)
#
# s	ei?	cos ? ? i sin ?	1 ? i tan ?
# At resonance ? = π/2 and As = i, using the fifirrsstt equality. On the other hand, while we usually think
#
# of ? as a real number, the fifinnaall
#
# expression above indicates that As becomes iinnfifinniittee for
# tan ? = ?i ,	(3.12)
#
#
# whatever that means! If we recall that tan iz = i tanh z we deduce that the above condition requires ? ? ?i∞, a rather strange result. At any rate, As becomes infinite, or has a pole, at tan ? = ?i. We will see that the large value |As| = 1 at resonance can be viewed as the “sshhaaddooww” of the iinnfifinniittee value
# As reaches nearby in the complex plane.
#
#
# Figure 8: In the complex k plane, resonances are identtiififieedd as poles of the scattering amplitude As located slightly below the real axis. Bound states appear as poles on positive imaginary axis.
#
#    Indeed, we can see how As behaves near resonance by inserting the near-resonance behavior (3.1) of ? into (3.11):
#
# As =
#
#  ?
# 	??k
#
# ?
# =	.	(3.13)
#
#
#  ? 	(? ? i?) ? k
# ??k
#
# When k = ?, meaning at the resonant energy, we get As = i, as expected. If we now think of the wavenumber k as a complex variable, we see that the pole of As is a pole at k = k? = ? ? i?. The
# real part of k? is the resonant energy, and the imaginary part ? encodes the lifetime. For small ?
# the resonance is a pole near the real axis, as illustrated in Figure 8. The smaller ? the sharper the resonance. As we can see, the value of |As| on the real line becomes large for k = ? because it is actually infinite a little below the axis.
#    The lesson in all of this is that we can indeed take (3.12) seriously and look for resonances by solving for the complex k values for which
#
# (3.14)
#
# The real part of those k’ss are the resonant energies. The imaginary parts give us the lifetime.
#    The idea of a complex k plane is very powerful. Suppose we consider purely imaginary k values of the form k = i?, with ? > 0. Then the energy takes the form
# n2?2
#
# E  = ?
# 2m
#
# < 0 ,	(3.15)
#
# which is suitable for bound states. Indeed one can show that bound states appear as poles of As along the positive imaginary axis, as shown in Figure 8. The complex k-plane has room to fit scattering states, resonances, and bound states!
#
# Sarah Geller transcribed Zwiebach’s handwritten notes to create the first LaTeX version of this docu- ment.
#
# MIT OpenCourseWare https://ocw.mit.edu
#
#
#
# 8.04 Quantum Physics I
# Spring 2016
#
#
#
# For information about citing these materials or our Terms of Use, visit: https://ocw.mit.edu/terms.
