# %% [markdown]
# # Lecture 8: Uncovering momentum space, Expectation values and their time dependence

# %% [markdown]
# ## 8.1	Uncovering momentum space
#
# ### We now begin a series of developments that lead to the idea of momentum space as a counterpoint or dual of position space. In this section the time dependence of wavefunctions will play no role. Therefore we will simply suppress time dependence. You can imagine all wavefunctions evaluated at time equal zero or at some arbitrary time $t_0$.
#
# ### We begin by recalling the key identities of Fourier’s theorem:
# ## $$ \begin{array} {rcl} \Psi(x) & = & \displaystyle \frac{1}{\sqrt{2\pi}} \int_{-\infty}^{\infty} \Phi(k) e^{ikx} \mathop{dk} \\ \Phi(k) & = & \displaystyle \frac{1}{\sqrt{2\pi}} \int_{-\infty}^{\infty} \Psi(x) e^{-ikx}\mathop{dx}  \end{array} \quad (1.1) $$
#
# ### The Fourier transform $\Phi(k)$ has all the information carried by the wavefunction $\Psi(x)$. This is clear because knowing $\Phi(k)$ means knowing $\Psi(x)$. The function $\Phi(k)$ also acts as the weight with which we add the plane waves with momentum $\hbar k$ to form $\Psi(x)$.
#
# ### We will now see that the consistency of the above equations can be used to derive an integral representation for a delta function. Such a representation is a needed tool for our upcoming discussion. The idea is to replace $\Phi(k)$ in the first equation by the value given in the second equation. In order to keep the notation clear, we must use $x'$ as a dummy variable of integration in the second equation.
#
# ### We have
# ## $$ \begin{array} {rcl} \Psi(x) & = & \displaystyle \frac{1}{\sqrt{2\pi}} \int_{-\infty}^{\infty} \mathop{dk} e^{ikx} \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{\infty} \mathop{dx'} e^{-ikx'} \Psi(x') \\ \, & = & \displaystyle  \int_{-\infty}^{\infty} \mathop{dx'} \Psi(x') \underbrace{\frac{1}{2\pi} \int_{-\infty}^{\infty} \mathop{dk} e^{ik(x-x')}}_{}  \end{array} \quad (1.2) $$
#
# ### Look at the type of integral. The factor indicated by the brace happens to reduce the $x'$ integral to an evaluation at $x$. We know that $\delta(x' - x)$ is the function such that for general $f(x)$,
# ## $$ \int_{-\infty}^{\infty} \mathop{dx'} f(x') \delta(x'-x) = f'(x) \quad (1.3) $$
#
# ### and so we conclude that the factor indicated by the brace is a delta function
# ## $$ \delta(x'-x) = \frac{1}{2\pi} \int_{-\infty}^{\infty} \mathop{dk} e^{ik(x-x')} \quad (1.4) $$
#
# ### In this integral one can let $k \rightarrow -k$ and since $\displaystyle \int dk$ is left-invariant under this replacement, we find that $\delta(x'-x) = \delta(x-x')$, or more plainly $\delta(x) = \delta(-x)$. We will record the integral representation of the delta function using the other sign:
# ## $$ \boxed{\delta(x-x') = \frac{1}{2\pi} \int_{-\infty}^{\infty} \mathop{dk} e^{ik(x-x')}} \quad (1.5) $$
#
# ### Another useful property of delta functions is
# ## $$ \delta(ax) = \frac{1}{|a|} \delta(x) \quad (1.6) $$
#
# ### At this point we ask: How does the normalization condition for $\Psi(x)$ look in terms of $\Phi(k)$? We must simply calculate.
#
# ### We have
# ## $$ \int_{-\infty}^{\infty} \mathop{dx} \Psi^*(x) \Psi(x) = \int_{-\infty}^{\infty} \mathop{dx} \frac{1}{\sqrt{2\pi}} \int_{-\infty}^{\infty} \Phi^*(k) e^{-ikx}\mathop{dk} \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{\infty} \Phi(k') e^{ik' x} \mathop{dk'} \quad (1.7) $$
#
# ### Rearranging the integrals to do the $x$ integral first we write
# ## $$ \begin{array} {rcl} \displaystyle \int_{-\infty}^{\infty} \mathop{dx} \Psi^*(x) \Psi(x) & = & \displaystyle \int_{-\infty}^{\infty} \mathop{dk} \int_{-\infty}^{\infty} \mathop{dk'} \Phi^*(k) \Phi(k') \frac{1}{2\pi} \int_{-\infty}^{\infty} \mathop{dx} e^{i(k'-k)x} \\ \, & = & \displaystyle \int_{-\infty}^{\infty} \mathop{dk} \mathop{dk'} \Phi^*(k) \Phi(k') \delta(k'-k) \\ \, & = & \displaystyle \int_{-\infty}^{\infty} \mathop{dk} \Phi^*(k) \Phi(k) \end{array} \quad(1.8) $$
#
# ### where we recognized the presence of a delta function and we did the integral over $k'$.
#
# ### Our final result is therefore
#
# (1.9)
#
# This is known as Parseval’s theorem, or more generally, Plancherel’s theorem. This equation relates the ?(x) normalization to a rather analogous normalization for ?(k). This is a hint that just like for
# 2	2
# |?(x)| , we may have a probability interpretation for |?(k)| .
#    Since physically we associate our plane waves with eigenstates of momentum, let us rewrite Par- seval’s theorem using momentum p = nk. Instead of integrals over k we will have integrals over p.
#
# Letting ?-(p) = ?(k) equations (1.1) become
#
# 1	r ∞
#
#
#
# ipx/n
#
# ?(x) = √2πn ?∞ ?-(p)e
#
# dp ,
#
#
# (1.10)
#
#  1  r ∞
#
# ?ipx/n
#
# ?-(p) = √2π  ?∞ ?(x)e	dx .
# For a more symmetric pair of equations we can redefine the function ?(p). We will let ?(p) ? ?(p)√n
# in equations (1.10). We then obtain our final form for Fourier’s relations in terms of momentum:
#
#
# (1.11)
#
# Similarly, Parseval’s theorem (1.9) becomes
#
# (1.12)
#
# Exercise. Verify that the redefinitions we did to arrive at (1.11) indeed yield (1.12) when starting from (1.9).
#    Our interpretation of the top equation in (1.11) is that ?(p) denotes the weight with which we add the momentum state eipx/n in the superposition that represents ?(x). This momentum state eipx/n is an eigenstate of the momentum operator pˆ with eigenvalue p. Just like we say that ?(x) is the wavefunction in position space x, we can think of ?(p) as the wavefunction in momentum space p. The Parseval identity (1.12) suggests that ?(p) has a probabilistic interpretation as well. Given that a properly normalized ?(x) leads to a ?(p) that satisfies  dp|?(p)|2 = 1, we postulate that:
#
# (1.13)
#
# This makes the analogy between position and momentum space quite complete.
# Let’s consider the generalization to 3D. Fourier’s theorem in momentum space language (namely, using
# p as opposed to k) takes the form
#
#
# (1.14)
#
#
# Just like we did in the 1D case, if we insert the Fourier transform into the expression for ?(x), we find an integral representation for the 3D ?-function
#
# ?(x) = 	1
# (2πn)3
#
# d3p eip·x/n r
#
# d3x? ?(x?)e?ip·x?/n
#
# = r
# = r
# which leads to the identification
#
# d3x? ?(x?) 	1
# (2πn)3
# d3x? ?(x?)   1
# (2π)3
#
# d3p eip·(x?x?)/n d3k eik·(x?x?),
#
#
# (1.15)
#
# ?3(x	x?) =   1
# (2π)3
#
# d3k eik·(x?x?).	(1.16)
#
# It is then straightforward to derive Parseval’s identity (exercise!). We find
#
# ∞
# d3x ?(x) 2
# ?∞
#
# = r d3p |?(p)|2 .	(1.17)
#
# We use in 3D momentum space the same probability interpretation: |?(p)|2d3p is the probability to find the particle with momentum in the range d p around p.

# %% [markdown]
# ## 8.2 Expectation Values of Operators
# Consider a random variable Q that takes values in the set {Q1, . . . , Qn} with respective probabilities
# {p1, . . . , pn}. The expectation value (Q) (or expected value) of Q is the average value that we expect to find after repeated observation of Q, and is given by the formula
# n
# (Q) =	Qipi.	(2.18)
# i=1
#
#    As we have seen, in a quantum system the probability for a particle to be found in [x, x + dx] at time t is given by
# ??(x, t)?(x, t) dx.	(2.19)
# Thus, the expected value of x, denoted as (xˆ) is given by
# r ∞	?
#
# Note that this expected value depends on t. What does (xˆ) correspond to physically? If we consider many copies of the physical system, and measure the position x at a time t in all of them, then the average value recorded will converge to (xˆ) as the number of measurements approaches infinity.
# Let’s discuss now the expectation value for the momentum. Since we have stated that
# ??(p, t)?(p, t) dp	(2.21)
# is the probability to find the particle with momentum in the range [p, p + dp] at time t, we define the expectation (pˆ) of the momentum operator as
# r ∞	?
#
#
# We will now manipulate this expression to see what form it takes in coordinate space. Using (1.11) and its complex conjugate version we have
# r ∞	?
#
#
# r ∞	r ∞  dx
#
#
# ipx/n	?
#
# r ∞	dx?
#
#
# ?ipx?/n	?
#
# =	dp p
# ?∞
#
# ?∞ √2πn e
#
# ? (x, t)
#
# ?∞ √2πn e
#
# ?(x , t)
#
#  1  r ∞
#
# ?	r ∞	?
#
# ?	r ∞	ipx/n
#
#
# ?ipx?/n
#
#
#
#  1  r ∞
#
# ?	r ∞	?
#
# ?	r ∞	 n ∂   ipx/n ?ipx?/n
#
#
#
# r ∞	?
#
# r ∞	?
#
# ?	 n ∂   1  r ∞
#
#
#
#
# ipx/n ?ipx?/n
#
# Letting p = nu in the final integral we have
#
#  1  r ∞
#
#
# ipx/n
#
# ?ipx?/n	 1  r ∞
#
#
# iu(x?x?)	?
#
# As a result, we have
#
# r ∞	?
#
# r ∞	?	?	 n ∂ 	?
#
# (pˆ) =
#
# dx ? (x, t)
# ?∞
#
# dx ?(x , t)
# ?∞
#
# i ∂x
#
# ?(x ? x )
#
#
# (2.25)
#
# r ∞	?
#
#  n ∂   r ∞	?	?	?
#
#
#
# where we changed the order of integration. The x? integral is now easily done and we find
# r ∞	?	 n ∂
#
#
#
# We have thus shown that
#
# (pˆ) =
#
# dx ? (x, t)
# ?∞
#
# i ∂x
#
# ?(x, t) ,	(2.26)
#
#
# (2.27)
#
# Notice the position of the pˆ operator: it acts on ?(x). This motivates the following definition for the expectation value (Qˆ) of any operator Qˆ:
#
# (2.28)
#
# Example: Consider the kinetic energy operator Tˆ for a particle moving in 1D:
#
# ˆ	pˆ2
#
# n2  ∂2
#
#
# The definition gives
#
# T = 2m = ? 2m ∂x2 .	(2.29)
#
# ˆ	n2 r
#
# ?	∂2
#
#
#
# The kinetic energy is a positive operator (being proportional to the square of the momentum operator). It is therefore of interest to make this positivity manifest. Integrating by parts one of the x derivatives and ignoring boundary terms that are presumed to vanish, we find
#
# ˆ	n2 r
#
# ∂?(x, t) 2
#
#
# (T ) = 2m	dx	∂x	.	(2.31)
# This is manifestly positive! The expectation value of Tˆ can also be computed in momentum space using the probabilistic interpretation that led to (2.22):
# ˆ	r	p2	2
#    Other examples of operators whose expectation values we can now compute are the momentum operator pˆ ? n ? in 3D, the potential energy operator, V (xˆ), and the angular momentum operator
# Lˆ = ˆr ? pˆ = ( yˆpˆz ? zˆpˆy , zˆpˆx ? xˆpˆz , xˆpˆy ? yˆpˆx)
#
# = n  y ∂ ? z ∂  , z ∂ ? x ∂  , x ∂ ? y ∂  .
#
# (2.33)

# %% [markdown]
# ## 8.3 Time dependence of expectation values
# The expectation values of operators are in general time dependent because the wavefunctions repre- senting the states are time dependent. We will consider here operators that do not have explicit time dependence, that is, operators that do no :
#
# in  d (Q) = in  d
#
# ∞
# d3x ??(x, t)Qˆ?(x, t)
#
# dt	dt ?∞
# r ∞
#
#
#
#
#  ∂??
#
#
#
# ∂?
#
# r ∞	 i	i
#
#
#
# (3.34)
#
# ∞
# =	d3x
# ?∞
#
#  ??QˆHˆ? ? (Hˆ??)Qˆ?
#
#
# We now recall the hermiticity of Hˆ, which implies that
# r ∞	?	r ∞	?
#
#
# This can be applied to the second term in the last right-hand side of (3.34) to move Hˆ
# wavefunction
#
#
# into the other
#
# d	∞
# 3	?	?
# i	(Q) =	d x	? QˆHˆ? ? ? HˆQˆ?
# dt	?∞
# r ∞	1	l	(3.36)
#
# where we noted the appearance of the commutator. All in all, we have proven that for operators Qˆ that do not explicitly depend on time,
#
# (3.37)
#
# Note that the commutator satisfies the following properties (homework):
# [A, B] = ? [B, A]	(3.38)
# [A, A] = 0	(3.39)
# [A, B + C] = [A, B] + [A, C]	(3.40)
# [A, BC] = [A, B] C + B [A, C]	(3.41)
# [AB, C] = A [B, C] + [A, C] B	(3.42)
# 0 = [A, [B, C]] + [B, [C, A]] + [C, [A, B]] .	(3.43)
#
# Andrew Turner transcribed Zwiebach’s handwritten notes to create the first LaTeX version of this document.
#
# MIT OpenCourseWare https://ocw.mit.edu
#
#
#
# 8.04 Quantum Physics I
# Spring 2016
#
#
#
# For information about citing these materials or our Terms of Use, visit: https://ocw.mit.edu/terms.
